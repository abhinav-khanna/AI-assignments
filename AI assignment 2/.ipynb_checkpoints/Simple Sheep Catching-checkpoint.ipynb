# %%
import random

# %%
rows = 8
columns = 8
MAX_MOVES = 100

# %%
def initialize_grid():
    man_1_row = random.randint(0,rows-1)
    man_1_col = random.randint(0,columns-1)
    man_2_row = random.randint(0,rows-1)
    man_2_col = random.randint(0,columns-1)
    sheep_row = random.randint(0,rows-1)
    sheep_col = random.randint(0,columns-1)
    
    return (man_1_row, man_1_col, man_2_row, man_2_col, sheep_row, sheep_col)

# %%
def winning_position(man_1_row, man_1_col, man_2_row, man_2_col, sheep_row, sheep_col):
#     print(abs(man_1_row - sheep_row))
#     print(abs(man_1_col - sheep_col))
#     print(abs(man_2_row - sheep_row))
#     print(abs(man_2_col - sheep_col))
    if man_1_row == sheep_row:
        if abs(man_1_col - sheep_col) == 1:
            return True
    
    if man_1_col == sheep_col:
        if abs(man_1_row - sheep_row) == 1:
            return True
    
    if man_2_row == sheep_row:
        if abs(man_2_col - sheep_col) == 1:
            return True
    
    if man_2_col == sheep_col:
        if abs(man_2_row - sheep_row) == 1:
            return True
        
    return False

# %%
def left_move_is_possible(man_1_col, man_2_col):
    if man_1_col == 0 or (man_2_col == man_1_col-1 and man_1_row == man_2_row):
        return False
    
    return True

# %%
def right_move_is_possible(man_1_col, man_2_col):
    if man_1_col == columns-1 or (man_2_col == man_1_col+1 and man_1_row == man_2_row):
        return False
    
    return True

# %%
def up_move_is_possible(man_1_row, man_2_row):
    if man_1_row == rows-1 or (man_2_row == man_1_row+1 and man_2_col == man_1_col):
        return False
    
    return True

# %%
def down_move_is_possible(man_1_row, man_2_row):
    if man_1_row == 0 or (man_2_row == man_1_row-1 and man_2_col == man_1_col):
        return False
    
    return True

# %%
def update_man_position(man_1_row, man_1_col, man_2_row, man_2_col, sheep_row, sheep_col):
    
    sheep_dist = abs(man_1_row - sheep_row) + abs(man_1_col - sheep_col)
    new_pos = ()
    
    if down_move_is_possible(man_1_row, man_2_row):
        print('down', end=':')
        print(abs(man_1_row-1 - sheep_row) + abs(man_1_col - sheep_col), end = ', ')
        if abs(man_1_row-1 - sheep_row) + abs(man_1_col - sheep_col) < sheep_dist:
            sheep_dist = abs(man_1_row-1 - sheep_row) + abs(man_1_col - sheep_col)
            new_pos = (man_1_row-1, man_1_col)
    
    if up_move_is_possible(man_1_row, man_2_row):
        print('up', end=':')
        print(abs(man_1_row+1 - sheep_row) + abs(man_1_col - sheep_col), end = ', ')
        if abs(man_1_row+1 - sheep_row) + abs(man_1_col - sheep_col) < sheep_dist:
            sheep_dist = abs(man_1_row+1 - sheep_row) + abs(man_1_col - sheep_col)
            new_pos = (man_1_row+1, man_1_col)
    
    if right_move_is_possible(man_1_col, man_2_col):
        print('right', end=':')
        print(abs(man_1_row - sheep_row) + abs(man_1_col+1 - sheep_col), end = ', ')
        if abs(man_1_row - sheep_row) + abs(man_1_col+1 - sheep_col) < sheep_dist:
            sheep_dist = abs(man_1_row - sheep_row) + abs(man_1_col+1 - sheep_col)
            new_pos = (man_1_row, man_1_col+1)
    
    if left_move_is_possible(man_1_col, man_2_col):
        print('left', end=':')
        print(abs(man_1_row - sheep_row) + abs(man_1_col-1 - sheep_col))
        if abs(man_1_row - sheep_row) + abs(man_1_col-1 - sheep_col) < sheep_dist:
            sheep_dist = abs(man_1_row - sheep_row) + abs(man_1_col-1 - sheep_col)
            new_pos = (man_1_row, man_1_col-1)
    
    print('sheep_dist:' + str(sheep_dist))
    
    if sheep_dist < abs(man_1_row - sheep_row) + abs(man_1_col - sheep_col):
        return new_pos
    else:
        return (man_1_row, man_1_col)

# %%
def single_up_right_move_possible(sheep_row, sheep_col):
    if sheep_row+1 < rows and sheep_col+1 < columns:
        return True
    
    return False

# %%
def single_down_right_move_possible(sheep_row, sheep_col):
    if sheep_row-1 >= 0 and sheep_col+1 < columns:
        return True
    
    return False

# %%
def single_down_left_move_possible(sheep_row, sheep_col):
    if sheep_row-1 >= 0 and sheep_col - 1 >= 0:
        return True
    
    return False

# %%
def single_up_left_move_possible(sheep_row, sheep_col):
    if sheep_row + 1 < rows and sheep_col - 1 >= 0 :
        return True
    
    return False

# %%
def double_up_right_move_possible(sheep_row, sheep_col):
    if sheep_row+2 < rows and sheep_col+2 < columns:
        return True
    
    return False

# %%
def double_down_right_move_possible(sheep_row, sheep_col):
    if sheep_row-2 >= 0 and sheep_col+2 < columns:
        return True
    
    return False

# %%
def double_down_left_move_possible(sheep_row, sheep_col):
    if sheep_row-2 >= 0 and sheep_col - 2 >= 0:
        return True
    
    return False

# %%
def double_up_left_move_possible(sheep_row, sheep_col):
    if sheep_row + 2 < rows and sheep_col - 2 >= 0 :
        return True
    
    return False

# %%
def manhattan_dist(row_a, col_a, row_b, col_b):
    return abs(row_a - row_b) + abs(col_a - col_b)

# %%
def dist_nearest_corner(sheep_row, sheep_col):
    return min(manhattan_dist(sheep_row, sheep_col, 0, 0), manhattan_dist(sheep_row, sheep_col, rows-1, 0), manhattan_dist(sheep_row, sheep_col, 0, columns-1), manhattan_dist(sheep_row, sheep_col, rows-1, columns-1))

# %%
def update_sheep_position(man_1_row, man_1_col, man_2_row, man_2_col, sheep_row, sheep_col):
    total_dist = 0
    new_pos = ()
    
    if up_right_move_possible(sheep_row, sheep_col):
        temp_dist = dist_nearest_corner(sheep_row+2, sheep_col+2) + manhattan_dist(sheep_row+2, sheep_col+2, man_1_row, man_1_col) + manhattan_dist(sheep_row+2, sheep_col+2, man_2_row, man_2_col)
        if temp_dist > total_dist:
            total_dist = temp_dist
            new_pos = (sheep_row+2, sheep_col+2)
        
    
    if down_right_move_possible(sheep_row, sheep_col):
        temp_dist = dist_nearest_corner(sheep_row-2, sheep_col+2) + manhattan_dist(sheep_row-2, sheep_col+2, man_1_row, man_1_col) + manhattan_dist(sheep_row-2, sheep_col+2, man_2_row, man_2_col)
        if temp_dist > total_dist:
            total_dist = temp_dist
            new_pos = (sheep_row-2, sheep_col+2)
    
    if down_left_move_possible(sheep_row, sheep_col):
        temp_dist = dist_nearest_corner(sheep_row-2, sheep_col-2) + manhattan_dist(sheep_row-2, sheep_col-2, man_1_row, man_1_col) + manhattan_dist(sheep_row-2, sheep_col-2, man_2_row, man_2_col)
        if temp_dist > total_dist:
            total_dist = temp_dist
            new_pos = (sheep_row-2, sheep_col-2)
    
    if up_left_move_possible(sheep_row, sheep_col):
        temp_dist = dist_nearest_corner(sheep_row+2, sheep_col-2) + manhattan_dist(sheep_row+2, sheep_col-2, man_1_row, man_1_col) + manhattan_dist(sheep_row+2, sheep_col-2, man_2_row, man_2_col)
        if temp_dist > total_dist:
            total_dist = temp_dist
            new_pos = (sheep_row+2, sheep_col-2)
    
#     if total_dist > 2:
#         return (sheep_row, sheep_col)
    
    return new_pos

# %%
(man_1_row, man_1_col, man_2_row, man_2_col, sheep_row, sheep_col) = initialize_grid()
# (man_1_row, man_1_col, man_2_row, man_2_col, sheep_row, sheep_col) = (4, 4, 3, 3, 6, 2)
print('initial position:' + str((man_1_row, man_1_col, man_2_row, man_2_col, sheep_row, sheep_col)))
if winning_position(man_1_row, man_1_col, man_2_row, man_2_col, sheep_row, sheep_col) == True:
    print('Position won')

for move in range(MAX_MOVES):
    (new_man_1_row, new_man_1_col) = update_man_position(man_1_row, man_1_col, man_2_row, man_2_col, sheep_row, sheep_col)
    (new_man_2_row, new_man_2_col) = update_man_position(man_2_row, man_2_col, man_1_row, man_1_col, sheep_row, sheep_col)
    (new_sheep_row, new_sheep_col) = update_sheep_position(man_1_row, man_1_col, man_2_row, man_2_col, sheep_row, sheep_col)
    
    
    (man_1_row, man_1_col) = (new_man_1_row, new_man_1_col)
    (man_2_row, man_2_col) = (new_man_2_row, new_man_2_col)
    (sheep_row, sheep_col) = (new_sheep_row, new_sheep_col)
    
    print((man_1_row, man_1_col), end = ', ' )
    print((man_2_row, man_2_col), end = ', ' )
    print((sheep_row, sheep_col))
    if winning_position(man_1_row, man_1_col, man_2_row, man_2_col, sheep_row, sheep_col) == True:
        print('Position won')
        break
# Out:
# initial position:(6, 0, 2, 3, 1, 7)
# down:11, up:13, right:11, sheep_dist:11
# down:4, up:6, right:4, left:6
# sheep_dist:4
# (5, 0), (1, 3), (3, 5)
# down:6, up:8, right:6, sheep_dist:6
# down:5, up:3, right:3, left:5
# sheep_dist:3
# (4, 0), (2, 3), (5, 7)
# down:9, up:7, right:7, sheep_dist:7
# down:8, up:6, right:6, left:8
# sheep_dist:6
# (5, 0), (3, 3), (7, 5)
# down:8, up:6, right:6, sheep_dist:6
# down:7, up:5, right:5, left:7
# sheep_dist:5
# (6, 0), (4, 3), (5, 7)
# down:7, up:9, right:7, sheep_dist:7
# down:6, up:4, right:4, left:6
# sheep_dist:4
# (5, 0), (5, 3), (3, 5)
# down:6, up:8, right:6, sheep_dist:6
# down:3, up:5, right:3, left:5
# sheep_dist:3
# (4, 0), (4, 3), (1, 7)
# down:9, up:11, right:9, sheep_dist:9
# down:6, up:8, right:6, left:8
# sheep_dist:6
# (3, 0), (3, 3), (3, 5)
# down:6, up:6, right:4, sheep_dist:4
# down:3, up:3, right:1, left:3
# sheep_dist:1
# (3, 1), (3, 4), (5, 7)
# down:9, up:7, right:7, left:9
# sheep_dist:7
# down:6, up:4, right:4, left:6
# sheep_dist:4
# (4, 1), (4, 4), (7, 5)
# down:8, up:6, right:6, left:8
# sheep_dist:6
# down:5, up:3, right:3, left:5
# sheep_dist:3
# (5, 1), (5, 4), (5, 7)
# down:7, up:7, right:5, left:7
# sheep_dist:5
# down:4, up:4, right:2, left:4
# sheep_dist:2
# (5, 2), (5, 5), (3, 5)
# down:4, up:6, right:4, left:6
# sheep_dist:4
# down:1, up:3, right:3, left:3
# sheep_dist:1
# (4, 2), (4, 5), (1, 7)
# down:7, up:9, right:7, left:9
# sheep_dist:7
# down:4, up:6, right:4, left:6
# sheep_dist:4
# (3, 2), (3, 5), (3, 5)
# down:4, up:4, right:2, left:4
# sheep_dist:2
# down:1, up:1, right:1, left:1
# sheep_dist:0
# (3, 3), (3, 5), (5, 7)
# down:7, up:5, right:5, left:7
# sheep_dist:5
# down:5, up:3, right:3, left:5
# sheep_dist:3
# (4, 3), (4, 5), (7, 5)
# down:6, up:4, right:4, left:6
# sheep_dist:4
# down:4, up:2, right:4, left:4
# sheep_dist:2
# (5, 3), (5, 5), (5, 7)
# down:5, up:5, right:3, left:5
# sheep_dist:3
# down:3, up:3, right:1, left:3
# sheep_dist:1
# (5, 4), (5, 6), (3, 5)
# down:2, up:4, right:2, left:4
# sheep_dist:2
# down:2, up:4, right:4, left:2
# sheep_dist:2
# (4, 4), (4, 6), (1, 3)
# down:3, up:5, right:5, left:3
# sheep_dist:3
# down:5, up:7, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (-1, 5)
# down:4, up:6, right:4, left:6
# sheep_dist:4
# down:4, up:6, right:6, left:4
# sheep_dist:4
# (2, 4), (2, 6), (1, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (1, 4), (1, 6), (3, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (2, 4), (2, 6), (5, 3)
# down:5, up:3, right:5, left:3
# sheep_dist:3
# down:7, up:5, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (7, 1)
# down:8, up:6, right:8, left:6
# sheep_dist:6
# down:10, up:8, right:10, left:8
# sheep_dist:8
# (4, 4), (4, 6), (5, 3)
# down:3, up:1, right:3, left:1
# sheep_dist:1
# down:5, up:3, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (7, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (6, 4), (6, 6), (5, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (3, 1)
# down:4, up:6, right:6, left:4
# sheep_dist:4
# down:6, up:8, right:8, left:6
# sheep_dist:6
# (4, 4), (4, 6), (1, 3)
# down:3, up:5, right:5, left:3
# sheep_dist:3
# down:5, up:7, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (-1, 5)
# down:4, up:6, right:4, left:6
# sheep_dist:4
# down:4, up:6, right:6, left:4
# sheep_dist:4
# (2, 4), (2, 6), (1, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (1, 4), (1, 6), (3, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (2, 4), (2, 6), (5, 3)
# down:5, up:3, right:5, left:3
# sheep_dist:3
# down:7, up:5, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (7, 1)
# down:8, up:6, right:8, left:6
# sheep_dist:6
# down:10, up:8, right:10, left:8
# sheep_dist:8
# (4, 4), (4, 6), (5, 3)
# down:3, up:1, right:3, left:1
# sheep_dist:1
# down:5, up:3, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (7, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (6, 4), (6, 6), (5, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (3, 1)
# down:4, up:6, right:6, left:4
# sheep_dist:4
# down:6, up:8, right:8, left:6
# sheep_dist:6
# (4, 4), (4, 6), (1, 3)
# down:3, up:5, right:5, left:3
# sheep_dist:3
# down:5, up:7, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (-1, 5)
# down:4, up:6, right:4, left:6
# sheep_dist:4
# down:4, up:6, right:6, left:4
# sheep_dist:4
# (2, 4), (2, 6), (1, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (1, 4), (1, 6), (3, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (2, 4), (2, 6), (5, 3)
# down:5, up:3, right:5, left:3
# sheep_dist:3
# down:7, up:5, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (7, 1)
# down:8, up:6, right:8, left:6
# sheep_dist:6
# down:10, up:8, right:10, left:8
# sheep_dist:8
# (4, 4), (4, 6), (5, 3)
# down:3, up:1, right:3, left:1
# sheep_dist:1
# down:5, up:3, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (7, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (6, 4), (6, 6), (5, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (3, 1)
# down:4, up:6, right:6, left:4
# sheep_dist:4
# down:6, up:8, right:8, left:6
# sheep_dist:6
# (4, 4), (4, 6), (1, 3)
# down:3, up:5, right:5, left:3
# sheep_dist:3
# down:5, up:7, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (-1, 5)
# down:4, up:6, right:4, left:6
# sheep_dist:4
# down:4, up:6, right:6, left:4
# sheep_dist:4
# (2, 4), (2, 6), (1, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (1, 4), (1, 6), (3, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (2, 4), (2, 6), (5, 3)
# down:5, up:3, right:5, left:3
# sheep_dist:3
# down:7, up:5, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (7, 1)
# down:8, up:6, right:8, left:6
# sheep_dist:6
# down:10, up:8, right:10, left:8
# sheep_dist:8
# (4, 4), (4, 6), (5, 3)
# down:3, up:1, right:3, left:1
# sheep_dist:1
# down:5, up:3, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (7, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (6, 4), (6, 6), (5, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (3, 1)
# down:4, up:6, right:6, left:4
# sheep_dist:4
# down:6, up:8, right:8, left:6
# sheep_dist:6
# (4, 4), (4, 6), (1, 3)
# down:3, up:5, right:5, left:3
# sheep_dist:3
# down:5, up:7, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (-1, 5)
# down:4, up:6, right:4, left:6
# sheep_dist:4
# down:4, up:6, right:6, left:4
# sheep_dist:4
# (2, 4), (2, 6), (1, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (1, 4), (1, 6), (3, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (2, 4), (2, 6), (5, 3)
# down:5, up:3, right:5, left:3
# sheep_dist:3
# down:7, up:5, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (7, 1)
# down:8, up:6, right:8, left:6
# sheep_dist:6
# down:10, up:8, right:10, left:8
# sheep_dist:8
# (4, 4), (4, 6), (5, 3)
# down:3, up:1, right:3, left:1
# sheep_dist:1
# down:5, up:3, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (7, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (6, 4), (6, 6), (5, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (3, 1)
# down:4, up:6, right:6, left:4
# sheep_dist:4
# down:6, up:8, right:8, left:6
# sheep_dist:6
# (4, 4), (4, 6), (1, 3)
# down:3, up:5, right:5, left:3
# sheep_dist:3
# down:5, up:7, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (-1, 5)
# down:4, up:6, right:4, left:6
# sheep_dist:4
# down:4, up:6, right:6, left:4
# sheep_dist:4
# (2, 4), (2, 6), (1, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (1, 4), (1, 6), (3, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (2, 4), (2, 6), (5, 3)
# down:5, up:3, right:5, left:3
# sheep_dist:3
# down:7, up:5, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (7, 1)
# down:8, up:6, right:8, left:6
# sheep_dist:6
# down:10, up:8, right:10, left:8
# sheep_dist:8
# (4, 4), (4, 6), (5, 3)
# down:3, up:1, right:3, left:1
# sheep_dist:1
# down:5, up:3, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (7, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (6, 4), (6, 6), (5, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (3, 1)
# down:4, up:6, right:6, left:4
# sheep_dist:4
# down:6, up:8, right:8, left:6
# sheep_dist:6
# (4, 4), (4, 6), (1, 3)
# down:3, up:5, right:5, left:3
# sheep_dist:3
# down:5, up:7, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (-1, 5)
# down:4, up:6, right:4, left:6
# sheep_dist:4
# down:4, up:6, right:6, left:4
# sheep_dist:4
# (2, 4), (2, 6), (1, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (1, 4), (1, 6), (3, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (2, 4), (2, 6), (5, 3)
# down:5, up:3, right:5, left:3
# sheep_dist:3
# down:7, up:5, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (7, 1)
# down:8, up:6, right:8, left:6
# sheep_dist:6
# down:10, up:8, right:10, left:8
# sheep_dist:8
# (4, 4), (4, 6), (5, 3)
# down:3, up:1, right:3, left:1
# sheep_dist:1
# down:5, up:3, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (7, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (6, 4), (6, 6), (5, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (3, 1)
# down:4, up:6, right:6, left:4
# sheep_dist:4
# down:6, up:8, right:8, left:6
# sheep_dist:6
# (4, 4), (4, 6), (1, 3)
# down:3, up:5, right:5, left:3
# sheep_dist:3
# down:5, up:7, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (-1, 5)
# down:4, up:6, right:4, left:6
# sheep_dist:4
# down:4, up:6, right:6, left:4
# sheep_dist:4
# (2, 4), (2, 6), (1, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (1, 4), (1, 6), (3, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (2, 4), (2, 6), (5, 3)
# down:5, up:3, right:5, left:3
# sheep_dist:3
# down:7, up:5, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (7, 1)
# down:8, up:6, right:8, left:6
# sheep_dist:6
# down:10, up:8, right:10, left:8
# sheep_dist:8
# (4, 4), (4, 6), (5, 3)
# down:3, up:1, right:3, left:1
# sheep_dist:1
# down:5, up:3, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (7, 1)
# down:6, up:4, right:6, left:4
# sheep_dist:4
# down:8, up:6, right:8, left:6
# sheep_dist:6
# (6, 4), (6, 6), (5, 3)
# down:1, up:3, right:3, left:1
# sheep_dist:1
# down:3, up:5, right:5, left:3
# sheep_dist:3
# (5, 4), (5, 6), (3, 1)
# down:4, up:6, right:6, left:4
# sheep_dist:4
# down:6, up:8, right:8, left:6
# sheep_dist:6
# (4, 4), (4, 6), (1, 3)
# down:3, up:5, right:5, left:3
# sheep_dist:3
# down:5, up:7, right:7, left:5
# sheep_dist:5
# (3, 4), (3, 6), (-1, 5)
# down:4, up:6, right:4, left:6
# sheep_dist:4
# down:4, up:6, right:6, left:4
# sheep_dist:4
# (2, 4), (2, 6), (1, 3)

# %%
a = ()
a = ((1,2))
min(1,2,3)
# Out:
# 1
